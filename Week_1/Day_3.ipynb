# %% [markdown]
# # Hallucination(n)

# %% [markdown]
# A phenomenon in which a system, especially a large language model or generative AI, produces outputs that are factually incorrect, fabricated, or not grounded in real data. (AI / NLP)
#
# Sentence: The paper discusses strategies to mitigate hallucination in large language models through retrieval-augmented generation.
#
# Verb: Hallucinate
#
# Adjective: Hallucinatory
#
# Collocations:
#
# model(n) **hallucination**
#
# factual(adj) **hallucination**
#
# **hallucination** rate(n)
#
# **hallucinate** response(n)
#
# **hallucination** detection(n)

# %% [markdown]
# # Generalization(n)

# %% [markdown]
# The ability of a model to perform well on unseen data or new tasks beyond the training set. (Machine Learning / Data Science)
#
# Sentence: Improving model generalization remains one of the key challenges in developing robust AI systems.
#
# Verb: Generalize
#
# Adjective: Generalizable
#
# Collocations:
#
# model(n) **generalization**
#
# **generalization** performance(n)
#
# strong(adj) **generalization**
#
# **generalize** data(n)
#
# **generalizable** feature(n)

# %% [markdown]
# # Regularization(n)

# %% [markdown]
# A technique used to prevent overfitting by adding constraints or penalties to the loss function during model training. (Machine Learning / Optimization)
#
# Sentence: The researchers applied L2 regularization to reduce overfitting and improve the stability of the neural network.
#
# Verb: Regularize
#
# Adjective: Regularized
#
# Collocations:
#
# L1(adj) **regularization**
#
# **regularization** technique(n)
#
# model(n) **regularization**
#
# **regularize** parameter(n)
#
# **regularization** strength(n)

# %% [markdown]
# # Benchmark(n)

# %% [markdown]
# A standard or set of tests used to evaluate the performance, accuracy, or efficiency of models and algorithms. (Computer Science / Machine Learning / Evaluation)
#
# Sentence: The newly proposed model achieved state-of-the-art performance on multiple vision-language benchmarks.
#
# Verb: Benchmark
#
# Adjective: Benchmarking(as participle adjective)
#
# Collocations:
#
# performance(n) **benchmark**
#
# **benchmark** dataset(n)
#
# **benchmark** evaluation(n)
#
# **benchmark** result(n)
#
# **benchmark** suite(n)

# %% [markdown]
# # Retrieval(n)

# %% [markdown]
# The process of locating and extracting relevant information from a database or knowledge source, often used in information retrieval systems and retrieval-augmented models. (Information Science / NLP)
#
# Sentence: The retrieval module enhanced the model's factual accuracy by grounding responses in external data sources.
#
# Verb: Retrieve
#
# Adjective: Retrieved
#
# Collocations:
#
# Information(n) **retrieval**
#
# **retrieval** system(n)
#
# document(n) **retrieval**
#
# **retrieval** accuracy(n)
#
# **retrieval** pipeline(n)

# %% [markdown]
# # Disentanglement(n)

# %% [markdown]
# The process of separating underlying factors of variation in learned representations to achieve more interpretable or controllable models. (Machine Learning / Representation Learning)
#
# Sentence: Disentanglement in latent spaces enables models to manipulate specific attributes without affecting others.
#
# Verb: Disentangle
#
# Adjective: Disentangled
#
# Collocations:
#
# Representation(n) **disentanglement**
#
# **disentangled** feature(n)
#
# latent(adj) **disentanglement**
#
# **disentangle** factor(n)
#
# **disentanglement** learning(n)

# %% [markdown]
# # Prompt(n)

# %% [markdown]
# A textual or multimodal input that guides the behavior or output of a generative model. (Generative AI / NLP / Vision-Language Models)
#
# Sentence: The study explores how prompt engineering can systematically control visual attributes in diffusion-based image generation.
#
# Verb: Prompt
#
# Adjective: Prompted
#
# Collocations:
#
# text(n) **prompt**
#
# **prompt** tuning(n)
#
# **prompt** engineering(n)
#
# multimodal(adj) **prompt**
#
# **prompt** template(n)

# %% [markdown]
# # Diffusion(n)

# %% [markdown]
# A generative modeling framework that synthesizes data by gradually denoising random noise through iterative refinement. (Computer Vision / Generative Modeling)
#
# Sentence: Diffusion models have surpassed GANs in image quality and diversity across various benchmarks.
#
# Verb: Diffuse
#
# Adjective: Diffusive
#
# Collocations:
#
# **diffusion** model(n)
#
# latent(adj) **diffusion**
#
# **diffusion** process(n)
#
# conditional(adj) **diffusion**
#
# **diffusion** step(n)

# %% [markdown]
# # Policy(n)

# %% [markdown]
# A function or strategy that defines an agent's behavior by mapping states to actions in reinforcement learning. (AI Agents / Reinforcement Learning)
#
# Sentence: The policy network was optimized using proximal policy optimizaiton to achieve stable learning performance.
#
# Adjective: Policy-based
#
# Collocations:
#
# reinforcement(n) **policy**
#
# **policy** optimization(n)
#
# **policy** gradient(n)
#
# **policy** network(n)
#
# stochastic(adj) **policy**

# %% [markdown]
# # Autonomy(n)

# %% [markdown]
# The capacity of an intelligent system or agent to operate independently, make decisions, and adapt to changing environments without explicit human control. (AI Agents / Robotics / Multi-Agent Systems)
#
# Sentence: Enhancing the autonomy of embodied AI agents is essential for scalable real-world deployment.
#
# Adjective: Autonomous
#
# Adverb: Autonomously
#
# Collocations:
#
# agent(n) **autonomy**
#
# **autonomous** system(n)
#
# **autonomy** level(n)
#
# operate(v) **autonomously**
#
# **autonomy** enhancement(n)
